# %%
from module import data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(context='paper', palette='deep')
sns.set_style('ticks')

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# #### 1. How many and what are WHO regions/continents contained in the dataset?

# %%
len(data['WHO Region'].unique())
# Out:
# 6

# %%
data['WHO Region'].unique()
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia'], dtype=object)

# %% [markdown]
# #### 2. How many countries?

# %%
len(data['Country'].unique())
# Out:
# 160

# %% [markdown]
# #### 3. Barplots

# %%
for c in data.select_dtypes(include=np.number):
  if c == 'Year':
    continue
  else:    
    fig = plt.figure(figsize=(10, 5))

    barplot = sns.barplot(
            data=data,
            x='WHO Region',
            y=c,
            dodge=False
        )
    
    barplot.tick_params(
            labelsize=10, 
            pad=5)
    
    sns.despine()

    plt.title(
            f'{c}',
            fontsize=15,
            fontweight='bold',
            pad = 20)

    plt.ylabel(
            'Count',
            fontsize=15
        )

    plt.xlabel(
            'Region according with World Health Organization',
            fontsize=15
        )

    plt.show()
    print('\n')

# %% [markdown]
# ## Conclusions:
# - The majority of cholera deaths reported originate from South-East Asia, despite the fact that the American continent has had a higher number of cases over the years.
